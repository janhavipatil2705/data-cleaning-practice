# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/HP/Downloads/messy_customer_sales_data.csv")
df
# Out:
#       Customer_ID               Name  Gender         Age         City  \
# 0        CUST4371        Paul Wilson      m           52     KOLKATA
# 1        CUST5957       Jason Thomas       M  51.0 years          NaN
# 2        CUST3754  Brittney Martinez       F          62   hyderabad
# 3        CUST2934      Brenda Pierce  FEMALE          40   hyderabad
# 4        CUST5683    Matthew Carroll      f           41     CHENNAI
# ...           ...                ...     ...         ...          ...
# 10195   CUST10767       Robert Lewis  female  35.0 years       delhi
# 10196         NaN        Diane Evans       M          53   bangalore
# 10197    CUST6315    Joshua Martinez      m           25   hyderabad
# 10198    CUST4812       Sarah Miller  FEMALE          55          NaN
# 10199    CUST6588       David Potter  female          34   HYDERABAD
#
#       Signup_Date Last_Purchase_Date  Purchase_Amount  Feedback_Score  \
# ...

# %%
df.shape
# Out:
# (10200, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10200 entries, 0 to 10199
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer_ID         9177 non-null   object
#  1   Name                10200 non-null  object
#  2   Gender              9174 non-null   object
#  3   Age                 9249 non-null   object
#  4   City                9184 non-null   object
#  5   Signup_Date         10200 non-null  object
#  6   Last_Purchase_Date  9188 non-null   object
#  7   Purchase_Amount     9179 non-null   float64
#  8   Feedback_Score      9177 non-null   float64
#  9   Email               10200 non-null  object
#  10  Phone_Number        10200 non-null  int64
#  11  Country             9468 non-null   object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 956.4+ KB

# %%
df.describe().round()
# Out:
#        Purchase_Amount  Feedback_Score  Phone_Number
# count           9179.0          9177.0  1.020000e+04
# mean           29090.0             5.0  4.979974e+09
# std           208697.0             3.0  2.902593e+09
# min             -500.0             1.0  9.208990e+05
# 25%            12295.0             3.0  2.449157e+09
# 50%            24330.0             5.0  4.988639e+09
# 75%            37130.0             8.0  7.510448e+09
# max          9999999.0            10.0  9.994402e+09

# %%
df.isnull().sum()
# Out:
# Customer_ID           1023
# Name                     0
# Gender                1026
# Age                    951
# City                  1016
# Signup_Date              0
# Last_Purchase_Date    1012
# Purchase_Amount       1021
# Feedback_Score        1023
# Email                    0
# Phone_Number             0
# Country                732
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#       Customer_ID               Name  Gender  Age         City Signup_Date  \
# 2032     CUST2755     Casey Campbell    male  NaN   Hyderabad   01-12-2023
# 3191          NaN   Travis Schneider      f    51          NaN  20-04-2025
# 4312     CUST8305       Stanley Cain  FEMALE   51   Bangalore   14-08-2023
# 5611     CUST6288       Jonathon Kim    male   46     Chennai   22-11-2023
# 5680     CUST2695        Lisa Durham     NaN   46     Chennai   18-04-2021
# 5899     CUST8841        Amanda Hill     NaN   34     chennai   11-09-2022
# 6070    CUST10780        Emily Smith     NaN   23     Kolkata   09-12-2023
# 6240     CUST9745      David Morales     NaN   56          NaN  18-02-2023
# 6425     CUST4631       George Villa      m    26      Mumbai   21-05-2022
# 6498     CUST1711  Stephanie Elliott     NaN   44      MUMBAI   17-05-2023
# 7118     CUST9380        Paul Wilson    MALE   42   Bangalore   31-07-2025
# ...

# %%
for i in df.columns:
    if df[i].nunique()<20:
        print(df[i].value_counts())
        print("-"*50)
# Out:
# Gender
# f         1184
# M         1171
# m         1163
# F         1157
# MALE      1131
# female    1128
# male      1121
# FEMALE    1119
# Name: count, dtype: int64
# --------------------------------------------------
# City
# Kolkata       820
# Mumbai        812
# Chennai       784
# Bangalore     773
# Hyderabad     770
# Delhi         763
# CHENNAI       404
# KOLKATA       395
# MUMBAI        393
# hyderabad     384
# bangalore     383
# DELHI         378
# delhi         369
# BANGALORE     363
# HYDERABAD     360
# mumbai        352
# chennai       343
# kolkata       338
# Name: count, dtype: int64
# --------------------------------------------------
# Feedback_Score
# 2.0     952
# 4.0     947
# 7.0     938
# 6.0     927
# 3.0     913
# 8.0     912
# 1.0     907
# 9.0     903
# 10.0    901
# 5.0     877
# Name: count, dtype: int64
# --------------------------------------------------
# Country
# India    7132
# IND       793
# india     772
# InDia     771
# ...

# %% [markdown]
# **Handling Missing Values**

# %%
df.isnull().sum()
# Out:
# Customer_ID           1023
# Name                     0
# Gender                1026
# Age                    951
# City                  1016
# Signup_Date              0
# Last_Purchase_Date    1012
# Purchase_Amount       1021
# Feedback_Score        1023
# Email                    0
# Phone_Number             0
# Country                732
# dtype: int64

# %%
df.dropna(subset = ["Customer_ID"],inplace=True)

# %%
df.isnull().sum()
# Out:
# Customer_ID             0
# Name                    0
# Gender                934
# Age                   859
# City                  918
# Signup_Date             0
# Last_Purchase_Date    914
# Purchase_Amount       927
# Feedback_Score        905
# Email                   0
# Phone_Number            0
# Country               664
# dtype: int64

# %%
df["Age"].unique()
# Out:
# array(['52', '51.0 years', '62', '40', '41', nan, '18', '43.0 years',
#        '40.0 years', '26', '32', '22', '59', '65', '61', '31',
#        '54.0 years', '55', '69', '61.0 years', '24', '63', '19', '50',
#        '56', '36', '68', '43', '38', '27', '57.0 years', '23', '25', '66',
#        '28', '30', '46', '48', '20', '37', '67', '51', '35', '58', '29',
#        'nan years', '39', '49', '47', '42', '44', '64', '53', '60',
#        '59.0 years', '45', '21', '34', '54', '48.0 years', '46.0 years',
#        '33', '57', '30.0 years', '58.0 years', '35.0 years', '34.0 years',
#        '69.0 years', '250', '19.0 years', '27.0 years', '53.0 years',
#        '65.0 years', '66.0 years', '44.0 years', '49.0 years',
#        '25.0 years', '23.0 years', '62.0 years', '41.0 years',
#        '33.0 years', '28.0 years', '22.0 years', '20.0 years',
#        '42.0 years', '45.0 years', '3', '63.0 years', '37.0 years',
#        '38.0 years', '55.0 years', '18.0 years', '36.0 years',
# ...

# %%
df['Age'] = df['Age'].str.replace(" years","",regex = False)

# %%
df["Age"].unique()
# Out:
# array(['52', '51.0', '62', '40', '41', nan, '18', '43.0', '40.0', '26',
#        '32', '22', '59', '65', '61', '31', '54.0', '55', '69', '61.0',
#        '24', '63', '19', '50', '56', '36', '68', '43', '38', '27', '57.0',
#        '23', '25', '66', '28', '30', '46', '48', '20', '37', '67', '51',
#        '35', '58', '29', 'nan', '39', '49', '47', '42', '44', '64', '53',
#        '60', '59.0', '45', '21', '34', '54', '48.0', '46.0', '33', '57',
#        '30.0', '58.0', '35.0', '34.0', '69.0', '250', '19.0', '27.0',
#        '53.0', '65.0', '66.0', '44.0', '49.0', '25.0', '23.0', '62.0',
#        '41.0', '33.0', '28.0', '22.0', '20.0', '42.0', '45.0', '3',
#        '63.0', '37.0', '38.0', '55.0', '18.0', '36.0', '67.0', '29.0',
#        '39.0', '31.0', '47.0', '52.0', '-10', '60.0', '24.0', '26.0',
#        '21.0', '64.0', '50.0', '68.0', '32.0', '56.0'], dtype=object)

# %%
df['Age'] = pd.to_numeric(df['Age'], errors = "coerce")

# %%
df.loc[(df['Age'] <0) | (df['Age']>100), "Age"] = None

# %%
df["Age"].unique()
# Out:
# array([52., 51., 62., 40., 41., nan, 18., 43., 26., 32., 22., 59., 65.,
#        61., 31., 54., 55., 69., 24., 63., 19., 50., 56., 36., 68., 38.,
#        27., 57., 23., 25., 66., 28., 30., 46., 48., 20., 37., 67., 35.,
#        58., 29., 39., 49., 47., 42., 44., 64., 53., 60., 45., 21., 34.,
#        33.,  3.])

# %%
median_age = int(df["Age"].median())
median_age
# Out:
# 43

# %%
df["Age"].fillna(median_age)
# Out:
# 0        52.0
# 1        51.0
# 2        62.0
# 3        40.0
# 4        41.0
#          ...
# 10194    40.0
# 10195    35.0
# 10197    25.0
# 10198    55.0
# 10199    34.0
# Name: Age, Length: 9177, dtype: float64

# %%
df["Age"].unique()
# Out:
# array([52., 51., 62., 40., 41., nan, 18., 43., 26., 32., 22., 59., 65.,
#        61., 31., 54., 55., 69., 24., 63., 19., 50., 56., 36., 68., 38.,
#        27., 57., 23., 25., 66., 28., 30., 46., 48., 20., 37., 67., 35.,
#        58., 29., 39., 49., 47., 42., 44., 64., 53., 60., 45., 21., 34.,
#        33.,  3.])

# %%
df["Age"] = df["Age"].fillna(median_age)

# %%
df["Age"].unique()
# Out:
# array([52., 51., 62., 40., 41., 43., 18., 26., 32., 22., 59., 65., 61.,
#        31., 54., 55., 69., 24., 63., 19., 50., 56., 36., 68., 38., 27.,
#        57., 23., 25., 66., 28., 30., 46., 48., 20., 37., 67., 35., 58.,
#        29., 39., 49., 47., 42., 44., 64., 53., 60., 45., 21., 34., 33.,
#         3.])

# %%
df.isnull().sum()
# Out:
# Customer_ID             0
# Name                    0
# Gender                934
# Age                     0
# City                  918
# Signup_Date             0
# Last_Purchase_Date    914
# Purchase_Amount       927
# Feedback_Score        905
# Email                   0
# Phone_Number            0
# Country               664
# dtype: int64

# %%
df
# Out:
#       Customer_ID               Name  Gender   Age         City Signup_Date  \
# 0        CUST4371        Paul Wilson      m   52.0     KOLKATA   26-06-2025
# 1        CUST5957       Jason Thomas       M  51.0          NaN  17-02-2021
# 2        CUST3754  Brittney Martinez       F  62.0   hyderabad   05-11-2023
# 3        CUST2934      Brenda Pierce  FEMALE  40.0   hyderabad   13-03-2022
# 4        CUST5683    Matthew Carroll      f   41.0     CHENNAI   05-04-2024
# ...           ...                ...     ...   ...          ...         ...
# 10194    CUST6146      Cody Thompson      f   40.0          NaN  21-08-2024
# 10195   CUST10767       Robert Lewis  female  35.0       delhi   08-12-2020
# 10197    CUST6315    Joshua Martinez      m   25.0   hyderabad   15-02-2022
# 10198    CUST4812       Sarah Miller  FEMALE  55.0          NaN  16-03-2021
# 10199    CUST6588       David Potter  female  34.0   HYDERABAD   12-10-2020
#
# ...

# %%
df['City'].unique()
# Out:
# array([' KOLKATA ', nan, ' hyderabad ', ' CHENNAI ', ' kolkata ',
#        ' BANGALORE ', ' Hyderabad ', ' HYDERABAD ', ' Mumbai ',
#        ' chennai ', ' Delhi ', ' bangalore ', ' Bangalore ', ' Kolkata ',
#        ' delhi ', ' Chennai ', ' MUMBAI ', ' DELHI ', ' mumbai '],
#       dtype=object)

# %%
median_amt = df['Purchase_Amount'].median()
median_amt
# Out:
# 24268.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9177 entries, 0 to 10199
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer_ID         9177 non-null   object
#  1   Name                9177 non-null   object
#  2   Gender              8243 non-null   object
#  3   Age                 9177 non-null   float64
#  4   City                8259 non-null   object
#  5   Signup_Date         9177 non-null   object
#  6   Last_Purchase_Date  8263 non-null   object
#  7   Purchase_Amount     9177 non-null   float64
#  8   Feedback_Score      8272 non-null   float64
#  9   Email               9177 non-null   object
#  10  Phone_Number        9177 non-null   int64
#  11  Country             8513 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 932.0+ KB

# %%
df['Purchase_Amount'] = df['Purchase_Amount'].fillna(median_amt)

# %%
df
# Out:
#       Customer_ID               Name  Gender   Age         City Signup_Date  \
# 0        CUST4371        Paul Wilson      m   52.0     KOLKATA   26-06-2025
# 1        CUST5957       Jason Thomas       M  51.0          NaN  17-02-2021
# 2        CUST3754  Brittney Martinez       F  62.0   hyderabad   05-11-2023
# 3        CUST2934      Brenda Pierce  FEMALE  40.0   hyderabad   13-03-2022
# 4        CUST5683    Matthew Carroll      f   41.0     CHENNAI   05-04-2024
# ...           ...                ...     ...   ...          ...         ...
# 10194    CUST6146      Cody Thompson      f   40.0          NaN  21-08-2024
# 10195   CUST10767       Robert Lewis  female  35.0       delhi   08-12-2020
# 10197    CUST6315    Joshua Martinez      m   25.0   hyderabad   15-02-2022
# 10198    CUST4812       Sarah Miller  FEMALE  55.0          NaN  16-03-2021
# 10199    CUST6588       David Potter  female  34.0   HYDERABAD   12-10-2020
#
# ...

# %%
df.isnull().sum()
# Out:
# Customer_ID             0
# Name                    0
# Gender                934
# Age                     0
# City                  918
# Signup_Date             0
# Last_Purchase_Date    914
# Purchase_Amount         0
# Feedback_Score        905
# Email                   0
# Phone_Number            0
# Country               664
# dtype: int64

# %%
feedback_mode = df['Feedback_Score'].mode()[0]
feedback_mode
# Out:
# np.float64(2.0)

# %%
df['Feedback_Score'] = df['Feedback_Score'].fillna(feedback_mode)

# %%
df.isnull().sum()
# Out:
# Customer_ID             0
# Name                    0
# Gender                934
# Age                     0
# City                  918
# Signup_Date             0
# Last_Purchase_Date    914
# Purchase_Amount         0
# Feedback_Score          0
# Email                   0
# Phone_Number            0
# Country               664
# dtype: int64

# %%
for i in ['Gender','City','Country']:
    df[i] = df[i].fillna(df[i].mode()[0])

# %%
df.isnull().sum()
# Out:
# Customer_ID           0
# Name                  0
# Gender                0
# Age                   0
# City                  0
# Signup_Date           0
# Last_Purchase_Date    0
# Purchase_Amount       0
# Feedback_Score        0
# Email                 0
# Phone_Number          0
# Country               0
# dtype: int64

# %%
df['Last_Purchase_Date'] = df['Last_Purchase_Date'].ffill()

# %%
df.isnull().sum()
# Out:
# Customer_ID           0
# Name                  0
# Gender                0
# Age                   0
# City                  0
# Signup_Date           0
# Last_Purchase_Date    0
# Purchase_Amount       0
# Feedback_Score        0
# Email                 0
# Phone_Number          0
# Country               0
# dtype: int64

# %% [markdown]
# **Fixing inconsistent datatypes**

# %%
df['Gender'].unique()
# Out:
# array(['m ', 'M', 'F', 'FEMALE', 'f ', 'male', 'MALE', 'female'],
#       dtype=object)

# %%
df['Gender'] = df['Gender'].str.lower().str.strip()

# %%
df['Gender'].unique()
# Out:
# array(['m', 'f', 'female', 'male'], dtype=object)

# %%
df['Gender'] = df['Gender'].replace({'Male':'male','Female':'female'})

# %%
df['Gender'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['City'].unique()
# Out:
# array([' KOLKATA ', ' Kolkata ', ' hyderabad ', ' CHENNAI ', ' kolkata ',
#        ' BANGALORE ', ' Hyderabad ', ' HYDERABAD ', ' Mumbai ',
#        ' chennai ', ' Delhi ', ' bangalore ', ' Bangalore ', ' delhi ',
#        ' Chennai ', ' MUMBAI ', ' DELHI ', ' mumbai '], dtype=object)

# %%
df['City'].str.title().str.strip().unique()
# Out:
# array(['Kolkata', 'Hyderabad', 'Chennai', 'Bangalore', 'Mumbai', 'Delhi'],
#       dtype=object)

# %%
df['City'] = df['City'].str.title().str.strip()

# %%
df['City'].unique()
# Out:
# array(['Kolkata', 'Hyderabad', 'Chennai', 'Bangalore', 'Mumbai', 'Delhi'],
#       dtype=object)

# %%
df['Country'].unique()
# Out:
# array(['India', 'india', 'InDia', 'IND'], dtype=object)

# %%
df['Country'] = df['Country'].str.title()

# %%
df['Country'].unique()
# Out:
# array(['India', 'Ind'], dtype=object)

# %%
df['Country'] = df['Country'].replace({'Ind':'India'})

# %%
df['Country'].unique()
# Out:
# array(['India'], dtype=object)

# %%
df
# Out:
#       Customer_ID               Name  Gender   Age       City Signup_Date  \
# 0        CUST4371        Paul Wilson    male  52.0    Kolkata  26-06-2025
# 1        CUST5957       Jason Thomas    male  51.0    Kolkata  17-02-2021
# 2        CUST3754  Brittney Martinez  female  62.0  Hyderabad  05-11-2023
# 3        CUST2934      Brenda Pierce  female  40.0  Hyderabad  13-03-2022
# 4        CUST5683    Matthew Carroll  female  41.0    Chennai  05-04-2024
# ...           ...                ...     ...   ...        ...         ...
# 10194    CUST6146      Cody Thompson  female  40.0    Kolkata  21-08-2024
# 10195   CUST10767       Robert Lewis  female  35.0      Delhi  08-12-2020
# 10197    CUST6315    Joshua Martinez    male  25.0  Hyderabad  15-02-2022
# 10198    CUST4812       Sarah Miller  female  55.0    Kolkata  16-03-2021
# 10199    CUST6588       David Potter  female  34.0  Hyderabad  12-10-2020
#
#       Last_Purchase_Date  Purchase_Amount  Feedback_Score  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9177 entries, 0 to 10199
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer_ID         9177 non-null   object
#  1   Name                9177 non-null   object
#  2   Gender              9177 non-null   object
#  3   Age                 9177 non-null   float64
#  4   City                9177 non-null   object
#  5   Signup_Date         9177 non-null   object
#  6   Last_Purchase_Date  9177 non-null   object
#  7   Purchase_Amount     9177 non-null   float64
#  8   Feedback_Score      9177 non-null   float64
#  9   Email               9177 non-null   object
#  10  Phone_Number        9177 non-null   int64
#  11  Country             9177 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 932.0+ KB

# %%
df.isnull().sum()
# Out:
# Customer_ID           0
# Name                  0
# Gender                0
# Age                   0
# City                  0
# Signup_Date           0
# Last_Purchase_Date    0
# Purchase_Amount       0
# Feedback_Score        0
# Email                 0
# Phone_Number          0
# Country               0
# dtype: int64

# %% [markdown]
# **Handling duplicates**

# %% [markdown]
# **Handling Duplicates**

# %%
df[df.duplicated()]
# Out:
#       Customer_ID               Name  Gender   Age       City Signup_Date  \
# 1956     CUST8512    Matthew Roberts    male  49.0  Bangalore  03-04-2023
# 1974     CUST6647      Julie Padilla  female  54.0      Delhi  13-12-2021
# 2032     CUST2755     Casey Campbell    male  43.0  Hyderabad  01-12-2023
# 2110     CUST7014  Phillip Rodriguez    male  57.0  Hyderabad  18-07-2021
# 2381     CUST5472      Linda Patrick    male  28.0    Kolkata  15-09-2025
# ...           ...                ...     ...   ...        ...         ...
# 10140    CUST4367      Amber Kennedy  female  61.0  Bangalore  05-11-2023
# 10158    CUST1317        Ashley Hall    male  55.0  Bangalore  14-01-2021
# 10182    CUST1740          Eric Rush  female  38.0    Kolkata  12-10-2023
# 10185    CUST7439      Kara Gallegos    male  35.0    Kolkata  15-08-2023
# 10199    CUST6588       David Potter  female  34.0  Hyderabad  12-10-2020
#
#       Last_Purchase_Date  Purchase_Amount  Feedback_Score  \
# ...

# %%
df[df.duplicated()].shape
# Out:
# (0, 12)

# %%
df.drop_duplicates(inplace = True)

# %%
df[df.duplicated()].shape
# Out:
# (0, 12)

# %%
df['Customer_ID'].value_counts()
# Out:
# Customer_ID
# CUST9534    2
# CUST4196    2
# CUST5341    2
# CUST2510    2
# CUST1002    2
#            ..
# CUST7618    1
# CUST2436    1
# CUST5982    1
# CUST5432    1
# CUST4812    1
# Name: count, Length: 9000, dtype: int64

# %%
df[df['Customer_ID']== 'CUST4196']
# Out:
#      Customer_ID        Name  Gender   Age     City Signup_Date  \
# 380     CUST4196  Erica Lane  female  59.0  Kolkata  28-07-2022
# 6342    CUST4196  Erica Lane  female  59.0  Kolkata  28-07-2022
#
#      Last_Purchase_Date  Purchase_Amount  Feedback_Score                Email  \
# 380          22-11-2024           2793.0             4.0  jcarter@example.com
# 6342         18-12-2024           2793.0             4.0  jcarter@example.com
#
#       Phone_Number Country
# 380     2106988000   India
# 6342    2106988000   India

# %%
df.drop_duplicates(subset = ['Customer_ID'],keep = "first",inplace = True)

# %% [markdown]
# **Correcting Datatypes**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9000 entries, 0 to 10198
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer_ID         9000 non-null   object
#  1   Name                9000 non-null   object
#  2   Gender              9000 non-null   object
#  3   Age                 9000 non-null   int64
#  4   City                9000 non-null   object
#  5   Signup_Date         9000 non-null   datetime64[ns]
#  6   Last_Purchase_Date  9000 non-null   object
#  7   Purchase_Amount     9000 non-null   float64
#  8   Feedback_Score      9000 non-null   float64
#  9   Email               9000 non-null   object
#  10  Phone_Number        9000 non-null   int64
#  11  Country             9000 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(7)
# memory usage: 914.1+ KB

# %%
df['Age'] = df['Age'].astype('int64')

# %%
df['Signup_Date'] = pd.to_datetime(df['Signup_Date'], format='%d-%m-%Y')

# %%
df['Last_Purchase_Date'] = pd.to_datetime(df['Last_Purchase_Date'], format='%d-%m-%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9000 entries, 0 to 10198
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer_ID         9000 non-null   object
#  1   Name                9000 non-null   object
#  2   Gender              9000 non-null   object
#  3   Age                 9000 non-null   int64
#  4   City                9000 non-null   object
#  5   Signup_Date         9000 non-null   datetime64[ns]
#  6   Last_Purchase_Date  9000 non-null   datetime64[ns]
#  7   Purchase_Amount     9000 non-null   float64
#  8   Feedback_Score      9000 non-null   float64
#  9   Email               9000 non-null   object
#  10  Phone_Number        9000 non-null   int64
#  11  Country             9000 non-null   object
# dtypes: datetime64[ns](2), float64(2), int64(2), object(6)
# memory usage: 914.1+ KB
